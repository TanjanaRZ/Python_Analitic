# %% [markdown]
# ## Условие 1:
# ### 1 задача
# - Скачать файл в уроке
# - Считать данные с помощью pandas
# - Вывести на экран первые 5 строк
# - Посмотреть на описание признаков и на их содержание

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from sklearn. linear_model import LinearRegression
from scipy.stats import bartlett
import platform
from typing import List, Dict
import pandas as pd
import datetime as dt

# %%
#df = pd.read_csv('kc_house_data (1).csv')
df = pd.read_csv('kc_house_data.csv', sep=',', encoding ='cp1251', quoting=3)

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Условие 2:
# ### 2 задача

# %% [markdown]
# - Проведите первичный анализ данных
# - Изучите типы данных
# - Найдите количество пропущенных ячеек в данных
# - Посчитайте основные статистики по всем признакам и поизучайте их
# - Пишите выводы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# **Вывод:** пропусков в данных таблицы нет. Типы данных в таблице 3: int64, float64, object.

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Условие 3:
# ### 3 задача

# %% [markdown]
# 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df['price'].min()
# Out:
# 75000.0

# %% [markdown]
# **Вывод:** Минимальная стоимость 75000.

# %%
df['price'].max()
# Out:
# 7700000.0

# %% [markdown]
# **Вывод:** Максимальная стоимость 7700000.

# %% [markdown]
# В диапазоне от 75000 до 77000000 изменяются стоимости недвижимости.

# %% [markdown]
# 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
p =2079.899736/1.510697e+04
p
# Out:
# 0.1376781535940033

# %% [markdown]
# **Вывод:** В среднем жилая площадь занимает от всей площади по всем домам - 14%

# %% [markdown]
# 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
df['floors'].nunique()
# Out:
# 6

# %% [markdown]
# **Вывод:** 6 значений количества этажей в данных: 1, 2, 1.5, 3, 2.5, 3.5.

# %% [markdown]
# 3.4 Насколько хорошие состояния у домов в данных?

# %%
df['condition'].value_counts(normalize=True)
# Out:
# 3    0.649193
# 4    0.262759
# 5    0.078703
# 2    0.007958
# 1    0.001388
# Name: condition, dtype: float64

# %% [markdown]
# 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
df['yr_built'].min()
# Out:
# 1900

# %%
df['yr_built'].max()
# Out:
# 2015

# %% [markdown]
# **Вывод:** Первый дом построили в 1900 году, а последний в 2015 году.

# %% [markdown]
# ## Условие 4:
# ### 4 задача

# %% [markdown]
# Ответьте на несколько вопросов
#
# 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df[df['bedrooms'] == 2]['price'].mean()
# Out:
# 401372.681884058

# %% [markdown]
# **Вывод:** Дома, у которых 2 спальни в среднем стоят 401373.

# %% [markdown]
# 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df['price'] > 600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %% [markdown]
# **Вывод:** В среднем общая площадь домов, у которых стоимость больше 600000 равна 20443.

# %% [markdown]
# 4.3 Как много домов коснулся ремонт?

# %%
df[df['yr_renovated']> 0]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 35     9547205180  20140613T000000   696000.0         3       2.50
# 95     1483300570  20140908T000000   905000.0         4       2.50
# 103    2450000295  20141007T000000  1088000.0         3       2.50
# 115    3626039325  20141121T000000   740500.0         3       3.50
# ...           ...              ...        ...       ...        ...
# 19622  7351200295  20150114T000000  1150000.0         3       1.75
# 20057   126039256  20140904T000000   434900.0         3       2.00
# 20444  4305600360  20150225T000000   500012.0         4       2.50
# 20447  3319500628  20150212T000000   356999.0         3       1.50
# 20962  1278000210  20150311T000000   110000.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %% [markdown]
# **Вывод:** 914 домов отремонтированы.

# %% [markdown]
# 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
df[df['grade'] > 10]['price'].mean()-df[df['grade'] < 4]['price'].mean()
# Out:
# 1488885.1175298805

# %% [markdown]
# **Вывод:** На 1488885 в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4.

# %% [markdown]
# ## Условие 5:
# ### 5 задача

# %% [markdown]
# Ответьте на несколько вопросов
#
# 5.1 Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df[(df['view'] == 'waterfront') & (df['bathrooms'] == 3) & (df['sqft_basement'] == 1)]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# **Вывод:** Подходящего дома в данных нет.

# %% [markdown]
# 5.2 Выберите дом клиенту
#
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
df1 = df[(df['view'] == 'waterfront') | (df['view'] == 4) & (df['yr_built'] > 1980)]
df1
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 409    1560930070  20140911T000000   840000.0         4       3.50
# 757    9273200140  20150121T000000  1310000.0         2       2.25
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# ...           ...              ...        ...       ...        ...
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 20923  7852070210  20140527T000000  1149000.0         4       3.00
# 21050  2424059170  20150219T000000   900000.0         5       6.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 246           3650      8354     1.0           1     4  ...      9
# ...

# %%
df1['price'].min()
# Out:
# 380000.0

# %%
df1['price'].max()
# Out:
# 6885000.0

# %% [markdown]
# **Вывод:** Подходящих домов в данных 108, с диапазоном цен от 380000 до 6885000.

# %% [markdown]
# 5.3 Выберите дом клиенту
#
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df2 = df[(df['sqft_basement'] == 0) & (df['floors'] == 2) & (df['price'] < 150000)]
df2
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# 18939          980      2490     2.0           0     0  ...      6
# 18988         1200      2002     2.0           0     0  ...      8
#
# ...

# %%
df2['condition'].mean()
# Out:
# 2.8333333333333335

# %% [markdown]
# **Вывод:** Подходящих домов в данных 6, со средней оценкой по состоянию 2,83.
